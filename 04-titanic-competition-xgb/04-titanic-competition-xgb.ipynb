# %% [markdown]
# # Titanic Competition - Deep Learning

# %%
# Setup plotting
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-whitegrid")
# Set Matplotlib defaults
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=18,
    titlepad=10,
)
plt.rc("animation", html="html5")

import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import KFold

from statistics import mean

import os

from utils import preprocess_data

# %% [markdown]
# ## Preprocessing

# %%
# Read the data
train_data = pd.read_csv("../input/train.csv").set_index("PassengerId")
test_data = pd.read_csv("../input/test.csv").set_index("PassengerId")

X, y, X_test = preprocess_data(
    train_data,
    test_data,
    label_value="Survived",
    cols_to_drop=["Name", "Ticket", "Cabin"],
)

# %% [markdown]
# ## Define the model

# %%
import xgboost as xgb

model = xgb.XGBClassifier()

# %% [markdown]
# ## Start testing

# %% [markdown]
# Key params for tuning:
#
# - Learning Rate (learning_rate)
#   - Definition: Controls the step size during each iteration of boosting.
#   - Effect: A smaller learning rate makes the model more robust, but it requires more boosting rounds (n_estimators) to converge.
#   - Typical Range: 0.01 to 0.3
# - Number of Trees (n_estimators)
#   - Definition: The number of boosting rounds or trees to build.
#   - Effect: More trees generally improve accuracy but increase the risk of overfitting and computational cost.
#   - Typical Range: 100 to 1000 (depending on the dataset and other parameters).
# - Maximum Depth of Trees (max_depth)
#   - Definition: Controls the maximum depth of each tree.
#   - Effect: Deeper trees capture more complex relationships but are prone to overfitting.
#   - Typical Range: 3 to 10 (higher values can lead to overfitting).
# - Subsample (subsample)
#   - Definition: Fraction of training data used for each tree.
#   - Effect: Helps prevent overfitting by building each tree on a random subset of data. Lower values make the model more robust but can slow down convergence.
#   - Typical Range: 0.5 to 1.0 (0.8 is common).
#
# Handle imbalanced data:
#
# - Scale Pos Weight (scale_pos_weight)
#   - Definition: Balances the positive and negative classes when they are imbalanced.
#   - Effect: Particularly useful for imbalanced classification problems by assigning higher weight to the minority class.
#   - Typical Range: Depends on the ratio of classes, typically set as #negative examples / #positive examples.

# %%
# Define the K-Fold cross-validator (K=5 in this example)
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# DataFrame that saves the parameters with accuracies
accuracies_df = pd.DataFrame(
    columns=[
        "learning_rate",
        "n_estimators",
        "max_depth",
        "subsample",
        "min_child_weight",
        "gamma",
        "reg_alpha",
        "reg_lambda",
        "scale_pos_weight",
        "accuracy",
    ]
)

# Handle imbalanced data
scale_pos_weight = sum(y == 0) / sum(y == 1)

# %% [markdown]
# ## Key parameter tuning
#
# learning_rate, n_estimators, max_depth, subsample

# %%
lr_values = [0.99, 0.1, 0.11, 0.12, 0.13, 0.14]
n_est_values = [50, 100]
max_dep_values = [5, 6, 7]
subsam_values = [0.5, 0.6, 0.7, 0.8, 0.9]


for lr in lr_values:
    for n_est in n_est_values:
        for max_dep in max_dep_values:
            for subsam in subsam_values:
                acc_list = []
                for train_index, val_index in kf.split(X):
                    # Split the data into training and testing sets
                    X_train, X_val = X[train_index], X[val_index]
                    y_train, y_val = y[train_index], y[val_index]

                    # Init the model in every iteration
                    model = xgb.XGBClassifier(
                        learning_rate=lr,
                        n_estimators=n_est,
                        max_depth=max_dep,
                        subsample=subsam,
                        scale_pos_weight=scale_pos_weight,
                    )

                    model.fit(X_train, y_train)
                    y_pred = model.predict(X_val)

                    acc_list.append(sum(y_pred == y_val) / len(y_val))

                print(
                    f"learning_rate: {lr}\t n_estimators: {n_est}\t max_depth: {max_dep}\t subsample: {subsam}\t accuracy: {mean(acc_list)}"
                )

                # Create a DataFrame for the new row
                new_row = pd.DataFrame(
                    [[lr, n_est, max_dep, subsam, scale_pos_weight, mean(acc_list)]],
                    columns=[
                        "learning_rate",
                        "n_estimators",
                        "max_depth",
                        "subsample",
                        "scale_pos_weight",
                        "accuracy",
                    ],
                )

                # Append the row using pd.concat()
                accuracies_df = pd.concat([accuracies_df, new_row], ignore_index=True)
# Out:
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 5	 subsample: 0.5	 accuracy: 0.7934592932019333
# C:\Users\kkleist\AppData\Local\Temp\ipykernel_29976\670332311.py:49: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   accuracies_df = pd.concat([accuracies_df, new_row], ignore_index=True)
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 5	 subsample: 0.6	 accuracy: 0.7755068733915008
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 5	 subsample: 0.7	 accuracy: 0.7968928504174252
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 5	 subsample: 0.8	 accuracy: 0.7990772707300232
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8002322515849601
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 6	 subsample: 0.5	 accuracy: 0.7923608059757705
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 6	 subsample: 0.6	 accuracy: 0.7777854497520558
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 6	 subsample: 0.7	 accuracy: 0.7968489109283786
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 6	 subsample: 0.8	 accuracy: 0.7867365513778168
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 6	 subsample: 0.9	 accuracy: 0.784514468646036
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 7	 subsample: 0.5	 accuracy: 0.7912372104701525
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 7	 subsample: 0.6	 accuracy: 0.782242169355345
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 7	 subsample: 0.7	 accuracy: 0.7890025735986441
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 7	 subsample: 0.8	 accuracy: 0.7789027681878099
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 7	 subsample: 0.9	 accuracy: 0.7946017199171427
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 5	 subsample: 0.5	 accuracy: 0.783390873140418
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 5	 subsample: 0.6	 accuracy: 0.7788839369782186
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8013684012303057
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 5	 subsample: 0.8	 accuracy: 0.7912246563304249
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 5	 subsample: 0.9	 accuracy: 0.7946017199171427
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 6	 subsample: 0.5	 accuracy: 0.777747787332873
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 6	 subsample: 0.6	 accuracy: 0.7676479819220388
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 6	 subsample: 0.7	 accuracy: 0.7878475927437072
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 6	 subsample: 0.8	 accuracy: 0.778871382838491
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 6	 subsample: 0.9	 accuracy: 0.7890088506685079
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 7	 subsample: 0.5	 accuracy: 0.7710375996484841
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 7	 subsample: 0.6	 accuracy: 0.7788588286987634
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 7	 subsample: 0.7	 accuracy: 0.7912309334002888
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 7	 subsample: 0.8	 accuracy: 0.7800138095537004
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 7	 subsample: 0.9	 accuracy: 0.7979536752244053
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8294017952419811
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8226790534178645
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8248948590797816
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 5	 subsample: 0.8	 accuracy: 0.827154604230745
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8260372857949909
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8338899001945892
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8249325214989642
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8293955181721172
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8260435628648547
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8338899001945892
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8383842822170611
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8316427091833533
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 7	 subsample: 0.7	 accuracy: 0.833896177264453
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 7	 subsample: 0.8	 accuracy: 0.829401795241981
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8361496453455527
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8249136902893729
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8271608813006088
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8271608813006088
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 5	 subsample: 0.8	 accuracy: 0.827154604230745
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8215554579122466
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8238026489234825
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8271734354403365
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8282907538760906
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8260561170045823
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8338836231247254
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8406503044378884
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8294206264515724
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8294269035214362
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8294143493817085
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8249199673592367
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8282781997363631
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8249199673592367
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8293955181721172
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8316427091833531
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 5	 subsample: 0.9	 accuracy: 0.833896177264453
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8282781997363631
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8327788588286987
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8350260498399348
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8271797125102003
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8282781997363631
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8361370912058251
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8260498399347185
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8327600276191074
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8271671583704726
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8383968363567886
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8170610758897746
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8294143493817087
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8226727763480007
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8316427091833531
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8327788588286987
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8260372857949909
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8316615403929446
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8260498399347185
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8293955181721172
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8305316678174628
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8316615403929446
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 7	 subsample: 0.6	 accuracy: 0.818203502604984
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8271671583704727
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8238089259933463
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8282844768062269
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8294143493817087
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8181846713953926
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8249011361496453
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8305316678174628
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 5	 subsample: 0.9	 accuracy: 0.829401795241981
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8338899001945892
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8271734354403365
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8305316678174628
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8305316678174628
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 6	 subsample: 0.9	 accuracy: 0.827154604230745
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 7	 subsample: 0.5	 accuracy: 0.831648986253217
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8260498399347185
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8260372857949909
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8361496453455527
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8305504990270541
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8260435628648547
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8226539451384094
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8260372857949909
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8294080723118449
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8294080723118449
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8271608813006088
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8271671583704726
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8260435628648547
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8249199673592367
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8282970309459544
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8294269035214362
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8226916075575921
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8271734354403365
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8226727763480007
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8181909484652564
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 5	 subsample: 0.5	 accuracy: 0.829401795241981
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8204318624066286
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8305316678174628
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8361433682756889
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8226602222082732
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8350009415604795
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8260561170045823
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 6	 subsample: 0.7	 accuracy: 0.829401795241981
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8327788588286987
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8181721172556651
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 7	 subsample: 0.5	 accuracy: 0.830525390747599
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8260498399347185
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8294080723118449
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8350197727700709
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8249387985688281
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8316615403929446
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8204318624066286
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8237963718536188
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8260372857949909
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8238026489234825
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8327788588286987
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8249262444291005
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8215617349821104
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8282970309459544
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8215554579122466
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8350260498399347
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8226978846274559
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8204381394764924
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8226853304877283
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8237963718536188
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8249136902893729
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 5	 subsample: 0.6	 accuracy: 0.823790094783755
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8282719226664993
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8316427091833533
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8316552633230808
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8305191136777352
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8204255853367648
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8282656455966355
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 6	 subsample: 0.8	 accuracy: 0.832772581758835
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8271608813006088
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8282907538760906
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8226790534178645
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8293955181721172
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8294080723118449
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8260435628648547
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8271483271608813
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8215680120519742
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8204318624066286
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8260498399347185
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8193082669010107
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8282907538760906
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8260435628648547
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8226602222082732
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8249136902893729
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8204255853367648
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8327914129684264
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8215617349821104
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8215554579122466
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8181972255351202
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8260498399347185

# %%
accuracies_df.sort_values(by="accuracy", ascending=False)
# Out:
#      learning_rate n_estimators max_depth  subsample min_child_weight gamma  \
# 55            0.10          100         7        0.5              NaN   NaN
# 74            0.11           50         7        0.9              NaN   NaN
# 40            0.10           50         7        0.5              NaN   NaN
# 44            0.10           50         7        0.9              NaN   NaN
# 103           0.12           50         7        0.8              NaN   NaN
# ..             ...          ...       ...        ...              ...   ...
# 6             0.99           50         6        0.6              NaN   NaN
# 20            0.99          100         6        0.5              NaN   NaN
# 1             0.99           50         5        0.6              NaN   NaN
# 25            0.99          100         7        0.5              NaN   NaN
# 21            0.99          100         6        0.6              NaN   NaN
#
#     reg_alpha reg_lambda  scale_pos_weight  accuracy
# 55        NaN        NaN          1.605263  0.840650
# 74        NaN        NaN          1.605263  0.838397
# 40        NaN        NaN          1.605263  0.838384
# 44        NaN        NaN          1.605263  0.836150
# 103       NaN        NaN          1.605263  0.836150
# ..        ...        ...               ...       ...
# 6         NaN        NaN          1.605263  0.777785
# 20        NaN        NaN          1.605263  0.777748
# 1         NaN        NaN          1.605263  0.775507
# 25        NaN        NaN          1.605263  0.771038
# 21        NaN        NaN          1.605263  0.767648
#
# [180 rows x 10 columns]

# %%
accuracies_df.to_csv("output/accuracies_tuning.csv")

# %% [markdown]
# Extract the parameters giving the highest value

# %%
accuracies_df_max_row = accuracies_df.loc[
    accuracies_df["accuracy"] == max(accuracies_df["accuracy"])
]
best_lr = accuracies_df_max_row["learning_rate"].iloc[0]
best_n_est = accuracies_df_max_row["n_estimators"].iloc[0]
best_max_dep = accuracies_df_max_row["max_depth"].iloc[0]
best_subsam = accuracies_df_max_row["subsample"].iloc[0]

# %% [markdown]
# ## Fine-tuning

# %% [markdown]
# Fine-tuning:
#
# - Minimum Child Weight (min_child_weight)
#   - Definition: Minimum sum of instance weights (hessian) needed in a child node.
#   - Effect: A larger value results in more conservative models, reducing the risk of overfitting by avoiding splitting nodes with insufficient instances.
#   - Typical Range: 1 to 10 (increase for highly imbalanced datasets).
# - Gamma (gamma)
#   - Definition: Minimum loss reduction required for further splitting a node.
#   - Effect: A higher value makes the algorithm more conservative, reducing the likelihood of overfitting by forcing the algorithm to focus on more significant splits.
#   - Typical Range: 0 to 5 (higher for noisy datasets).
# - Regularization (reg_alpha, reg_lambda)
#   - Definition:
#     - reg_alpha (L1 regularization): Adds L1 regularization, making some weights zero (similar to Lasso regression).
#     - reg_lambda (L2 regularization): Adds L2 regularization (similar to Ridge regression).
#   - Effect: Helps control model complexity and reduce overfitting, particularly in high-dimensional datasets.
#   - Typical Range:
#     - reg_alpha: 0 to 1 (higher values reduce complexity).
#     - reg_lambda: 1 to 5 (higher values reduce overfitting).

# %%
# DataFrame that saves the parameters with accuracies for fine-tuning
accuracies_ft_df = pd.DataFrame(
    columns=[
        "learning_rate",
        "n_estimators",
        "max_depth",
        "subsample",
        "min_child_weight",
        "gamma",
        "reg_alpha",
        "reg_lambda",
        "scale_pos_weight",
        "accuracy",
    ]
)

# %%
min_w_values = [1, 1.025, 1.05]
gam_values = [0, 0.025, 0.05]
reg_a_values = [0, 0.025, 0.05]
reg_l_values = [1, 1.05, 1.1]


for min_w in min_w_values:
    for gam in gam_values:
        for reg_a in reg_a_values:
            for reg_l in reg_l_values:
                acc_list = []
                for train_index, val_index in kf.split(X):
                    # Split the data into training and testing sets
                    X_train, X_val = X[train_index], X[val_index]
                    y_train, y_val = y[train_index], y[val_index]

                    # Init the model in every iteration
                    model = xgb.XGBClassifier(
                        learning_rate=best_lr,
                        n_estimators=best_n_est,
                        max_depth=best_max_dep,
                        subsample=best_subsam,
                        min_child_weight=min_w,
                        gamma=gam,
                        reg_alpha=reg_a,
                        reg_lambda=reg_l,
                        scale_pos_weight=scale_pos_weight,
                    )

                    model.fit(X_train, y_train)
                    y_pred = model.predict(X_val)

                    acc_list.append(sum(y_pred == y_val) / len(y_val))

                print(
                    f"min_child_weight: {min_w}\t gamma: {gam}\t reg_alpha: {reg_a}\t reg_lambda: {reg_l}\t accuracy: {mean(acc_list)}"
                )

                # Create a DataFrame for the new row
                new_row = pd.DataFrame(
                    [
                        [
                            best_lr,
                            best_n_est,
                            best_max_dep,
                            best_subsam,
                            min_w,
                            gam,
                            reg_a,
                            reg_l,
                            scale_pos_weight,
                            mean(acc_list),
                        ]
                    ],
                    columns=[
                        "learning_rate",
                        "n_estimators",
                        "max_depth",
                        "subsample",
                        "min_child_weight",
                        "gamma",
                        "reg_alpha",
                        "reg_lambda",
                        "scale_pos_weight",
                        "accuracy",
                    ],
                )

                # Append the row using pd.concat()
                accuracies_ft_df = pd.concat(
                    [accuracies_ft_df, new_row], ignore_index=True
                )
# Out:
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.8406503044378884
# C:\Users\kkleist\AppData\Local\Temp\ipykernel_29976\2513178999.py:70: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   accuracies_ft_df = pd.concat(
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8327851358985625
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8316615403929446
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8294143493817087
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8249387985688281
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8361433682756889
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8249199673592367
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8361370912058251
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8361559224154165
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.8350323269097985
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8282970309459544
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8350197727700709
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8339087314041805
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8249325214989642
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8361559224154165
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8305504990270541
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8305379448873266
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8327851358985625
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.8350260498399348
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8294269035214362
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8406440273680246
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8339275626137719
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8282844768062269
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8305442219571904
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.822666499278137
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8350260498399348
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8316803716025359
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.8238089259933463
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8339087314041805
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8327788588286987
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8350260498399347
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8406440273680246
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8339150084740443
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8271734354403365
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8350386039796623
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8271608813006088
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.8395078777226791
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8361496453455527
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8316740945326722
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8271608813006088
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8316740945326722
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8271859895800641
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8339212855439081
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8327914129684264
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8226853304877283
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.8372732408511707
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8339024543343168
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8316615403929446
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8305316678174628
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8294206264515724
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8350260498399348
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8372857949908983
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8327976900382902
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8327851358985625
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.8383905592869249
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8339024543343168
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8384031134266524
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8305379448873266
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8350386039796623
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8294269035214362
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8316615403929446
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.833896177264453
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8294206264515724
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.8282970309459544
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8249262444291005
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8271797125102003
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8316678174628084
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.841755068733915
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8339150084740443
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8339024543343168
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8294206264515724
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8350323269097985
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.8327788588286987
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8316740945326722
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8383968363567886
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8383968363567886
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8372732408511707
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8339087314041805
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8305442219571904
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8316552633230808
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8316740945326722

# %%
accuracies_ft_df.sort_values(by="accuracy", ascending=False)
# Out:
#     learning_rate n_estimators max_depth  subsample min_child_weight  gamma  \
# 67            0.1          100         7        0.5             1.05  0.025
# 0             0.1          100         7        0.5                1      0
# 20            0.1          100         7        0.5                1   0.05
# 31            0.1          100         7        0.5            1.025      0
# 36            0.1          100         7        0.5            1.025  0.025
# ..            ...          ...       ...        ...              ...    ...
# 64            0.1          100         7        0.5             1.05  0.025
# 6             0.1          100         7        0.5                1      0
# 27            0.1          100         7        0.5            1.025      0
# 44            0.1          100         7        0.5            1.025  0.025
# 24            0.1          100         7        0.5                1   0.05
#
#    reg_alpha reg_lambda  scale_pos_weight  accuracy
# 67     0.025       1.05          1.605263  0.841755
# 0          0          1          1.605263  0.840650
# 20         0        1.1          1.605263  0.840644
# 31     0.025       1.05          1.605263  0.840644
# 36         0          1          1.605263  0.839508
# ..       ...        ...               ...       ...
# 64         0       1.05          1.605263  0.824926
# 6       0.05          1          1.605263  0.824920
# 27         0          1          1.605263  0.823809
# 44      0.05        1.1          1.605263  0.822685
# 24      0.05          1          1.605263  0.822666
#
# [81 rows x 10 columns]

# %%
accuracies_ft_df.to_csv("output/accuracies_fine_tuning.csv")

# %% [markdown]
# Extract the parameters giving the highest value

# %%
accuracies_ft_df_max_row = accuracies_ft_df.loc[
    accuracies_ft_df["accuracy"] == max(accuracies_ft_df["accuracy"])
]
best_min_w = accuracies_ft_df_max_row["min_child_weight"].iloc[0]
best_gam = accuracies_ft_df_max_row["gamma"].iloc[0]
best_reg_a = accuracies_ft_df_max_row["reg_alpha"].iloc[0]
best_reg_l = accuracies_ft_df_max_row["reg_lambda"].iloc[0]

# %% [markdown]
# ## Submit prediction

# %%
model = xgb.XGBClassifier(
    learning_rate=best_lr,
    n_estimators=best_n_est,
    max_depth=best_max_dep,
    subsample=best_subsam,
    min_child_weight=best_min_w,
    gamma=best_gam,
    reg_alpha=best_reg_a,
    reg_lambda=best_reg_l,
    scale_pos_weight=scale_pos_weight,
)

model.fit(X, y)
y_pred = model.predict(X_test)

# %%
predictions = y_pred

# Saving the predictions
output = pd.DataFrame({"PassengerId": test_data.index, "Survived": predictions})
if not os.path.isdir("output/"):
    os.mkdir("output/")
output.to_csv("output/submission.csv", index=False)

print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!
