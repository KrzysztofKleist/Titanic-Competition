# %% [markdown]
# # Titanic Competition - Deep Learning

# %%
# Setup plotting
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-whitegrid")
# Set Matplotlib defaults
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=18,
    titlepad=10,
)
plt.rc("animation", html="html5")

import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import KFold

from statistics import mean

import os

from utils import preprocess_data

# %% [markdown]
# ## Preprocessing

# %%
# Read the data
train_data = pd.read_csv("../input/train.csv").set_index("PassengerId")
test_data = pd.read_csv("../input/test.csv").set_index("PassengerId")

X, y, X_test = preprocess_data(
    train_data,
    test_data,
    label_value="Survived",
)

# %% [markdown]
# ## Define the model

# %%
import xgboost as xgb

model = xgb.XGBClassifier()

# %% [markdown]
# ## Start testing

# %% [markdown]
# Key params for tuning:
#
# - Learning Rate (learning_rate)
#   - Definition: Controls the step size during each iteration of boosting.
#   - Effect: A smaller learning rate makes the model more robust, but it requires more boosting rounds (n_estimators) to converge.
#   - Typical Range: 0.01 to 0.3
# - Number of Trees (n_estimators)
#   - Definition: The number of boosting rounds or trees to build.
#   - Effect: More trees generally improve accuracy but increase the risk of overfitting and computational cost.
#   - Typical Range: 100 to 1000 (depending on the dataset and other parameters).
# - Maximum Depth of Trees (max_depth)
#   - Definition: Controls the maximum depth of each tree.
#   - Effect: Deeper trees capture more complex relationships but are prone to overfitting.
#   - Typical Range: 3 to 10 (higher values can lead to overfitting).
# - Subsample (subsample)
#   - Definition: Fraction of training data used for each tree.
#   - Effect: Helps prevent overfitting by building each tree on a random subset of data. Lower values make the model more robust but can slow down convergence.
#   - Typical Range: 0.5 to 1.0 (0.8 is common).
#
# Handle imbalanced data:
#
# - Scale Pos Weight (scale_pos_weight)
#   - Definition: Balances the positive and negative classes when they are imbalanced.
#   - Effect: Particularly useful for imbalanced classification problems by assigning higher weight to the minority class.
#   - Typical Range: Depends on the ratio of classes, typically set as #negative examples / #positive examples.

# %%
# Define the K-Fold cross-validator (K=5 in this example)
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# DataFrame that saves the parameters with accuracies
accuracies_df = pd.DataFrame(
    columns=[
        "learning_rate",
        "n_estimators",
        "max_depth",
        "subsample",
        "min_child_weight",
        "gamma",
        "reg_alpha",
        "reg_lambda",
        "scale_pos_weight",
        "accuracy",
    ]
)

# Handle imbalanced data
scale_pos_weight = sum(y == 0) / sum(y == 1)

# %% [markdown]
# ## Key parameter tuning
#
# learning_rate, n_estimators, max_depth, subsample

# %%
lr_values = [0.99, 0.1, 0.11, 0.12, 0.13, 0.14]
n_est_values = [50, 100]
max_dep_values = [5, 6, 7]
subsam_values = [0.5, 0.6, 0.7, 0.8, 0.9]


for lr in lr_values:
    for n_est in n_est_values:
        for max_dep in max_dep_values:
            for subsam in subsam_values:
                acc_list = []
                for train_index, val_index in kf.split(X):
                    # Split the data into training and testing sets
                    X_train, X_val = X[train_index], X[val_index]
                    y_train, y_val = y[train_index], y[val_index]

                    # Init the model in every iteration
                    model = xgb.XGBClassifier(
                        learning_rate=lr,
                        n_estimators=n_est,
                        max_depth=max_dep,
                        subsample=subsam,
                        scale_pos_weight=scale_pos_weight,
                    )

                    model.fit(X_train, y_train)
                    y_pred = model.predict(X_val)

                    acc_list.append(sum(y_pred == y_val) / len(y_val))

                print(
                    f"learning_rate: {lr}\t n_estimators: {n_est}\t max_depth: {max_dep}\t subsample: {subsam}\t accuracy: {mean(acc_list)}"
                )

                # Create a DataFrame for the new row
                new_row = pd.DataFrame(
                    [[lr, n_est, max_dep, subsam, scale_pos_weight, mean(acc_list)]],
                    columns=[
                        "learning_rate",
                        "n_estimators",
                        "max_depth",
                        "subsample",
                        "scale_pos_weight",
                        "accuracy",
                    ],
                )

                # Append the row using pd.concat()
                accuracies_df = pd.concat([accuracies_df, new_row], ignore_index=True)
# Out:
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 5	 subsample: 0.5	 accuracy: 0.7991023790094783
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8058376749733225
# C:\Users\kkleist\AppData\Local\Temp\ipykernel_7748\670332311.py:49: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   accuracies_df = pd.concat([accuracies_df, new_row], ignore_index=True)
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8036030381018141
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 5	 subsample: 0.8	 accuracy: 0.7980038917833155
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8058188437637311
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 6	 subsample: 0.5	 accuracy: 0.7845207457158998
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 6	 subsample: 0.6	 accuracy: 0.7912434875400163
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 6	 subsample: 0.7	 accuracy: 0.7968551879982424
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8080785889146946
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 6	 subsample: 0.9	 accuracy: 0.809221015629904
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 7	 subsample: 0.5	 accuracy: 0.7822610005649363
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 7	 subsample: 0.6	 accuracy: 0.7901324461741259
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 7	 subsample: 0.7	 accuracy: 0.795744146632352
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8114493754315486
# learning_rate: 0.99	 n_estimators: 50	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8035842068922228
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 5	 subsample: 0.5	 accuracy: 0.7934718473416609
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8069738246186681
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 5	 subsample: 0.7	 accuracy: 0.7934906785512523
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 5	 subsample: 0.8	 accuracy: 0.797991337643588
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 5	 subsample: 0.9	 accuracy: 0.806942439269349
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 6	 subsample: 0.5	 accuracy: 0.784514468646036
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8024982738057874
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 6	 subsample: 0.7	 accuracy: 0.7923608059757705
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8148076078086749
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8125980792166216
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 7	 subsample: 0.5	 accuracy: 0.7856568953612454
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 7	 subsample: 0.6	 accuracy: 0.7833783190006904
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 7	 subsample: 0.7	 accuracy: 0.7957504237022158
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8136902893729208
# learning_rate: 0.99	 n_estimators: 100	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8092021844203126
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8294080723118449
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8350260498399347
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8350197727700709
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8327851358985625
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8339087314041805
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8249387985688281
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8305504990270541
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8327914129684264
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8316427091833533
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8395204318624067
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8372544096415793
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8271859895800641
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8350260498399348
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8361496453455527
# learning_rate: 0.1	 n_estimators: 50	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8350134957002071
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8283033080158182
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8316678174628084
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 5	 subsample: 0.7	 accuracy: 0.833896177264453
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8339024543343168
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8383968363567886
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8271734354403365
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8327914129684263
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8226978846274559
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8305191136777352
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8282907538760906
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8249262444291005
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8350260498399347
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8282970309459544
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8350134957002071
# learning_rate: 0.1	 n_estimators: 100	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8316615403929446
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8327851358985625
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8238089259933463
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 5	 subsample: 0.7	 accuracy: 0.832772581758835
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8249262444291006
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 5	 subsample: 0.9	 accuracy: 0.832772581758835
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8294080723118449
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8271797125102003
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8305191136777352
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 6	 subsample: 0.8	 accuracy: 0.831648986253217
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8294269035214362
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8282719226664993
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8282970309459544
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8361308141359614
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8361559224154165
# learning_rate: 0.11	 n_estimators: 50	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8395078777226791
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8260372857949909
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8226790534178645
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8260310087251271
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8316615403929446
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8395016006528153
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8226853304877283
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8361621994852803
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 6	 subsample: 0.7	 accuracy: 0.831648986253217
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8316427091833533
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8294080723118448
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8249262444291005
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8305567760969179
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8316552633230808
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8271859895800641
# learning_rate: 0.11	 n_estimators: 100	 max_depth: 7	 subsample: 0.9	 accuracy: 0.832772581758835
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8316615403929446
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8238026489234825
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8361433682756889
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8260372857949909
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8350511581193899
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8226853304877283
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8294206264515724
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8316552633230808
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8282844768062269
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8395267089322704
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8361496453455527
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8316740945326722
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 7	 subsample: 0.7	 accuracy: 0.833896177264453
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8406377502981608
# learning_rate: 0.12	 n_estimators: 50	 max_depth: 7	 subsample: 0.9	 accuracy: 0.833896177264453
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 5	 subsample: 0.5	 accuracy: 0.818203502604984
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8260435628648547
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8383905592869249
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8271608813006088
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8327788588286987
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8249262444291005
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8294143493817087
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8260498399347185
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8316615403929446
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8361496453455527
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8372857949908983
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8271859895800641
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8294143493817087
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8260372857949909
# learning_rate: 0.12	 n_estimators: 100	 max_depth: 7	 subsample: 0.9	 accuracy: 0.824938798568828
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8361433682756889
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8249199673592367
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8372857949908983
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8283033080158182
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8350260498399348
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8395141547925429
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 6	 subsample: 0.6	 accuracy: 0.833896177264453
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8316678174628084
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8282719226664993
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8327851358985625
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8361370912058251
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8282907538760906
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8305504990270541
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8316740945326722
# learning_rate: 0.13	 n_estimators: 50	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8372732408511707
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8271608813006088
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 5	 subsample: 0.6	 accuracy: 0.8339150084740443
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8294269035214362
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8226916075575921
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8395078777226791
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8260498399347185
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8271671583704726
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8305379448873266
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8249199673592367
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8294269035214362
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8282844768062269
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8215617349821104
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8350386039796623
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8260498399347185
# learning_rate: 0.13	 n_estimators: 100	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8327788588286987
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8316552633230808
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 5	 subsample: 0.6	 accuracy: 0.829401795241981
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8361433682756889
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8226790534178645
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 5	 subsample: 0.9	 accuracy: 0.832772581758835
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8395267089322704
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8305442219571904
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8316615403929446
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8249325214989642
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8339087314041805
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 7	 subsample: 0.5	 accuracy: 0.837260686711443
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8260372857949909
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8316552633230808
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8361496453455527
# learning_rate: 0.14	 n_estimators: 50	 max_depth: 7	 subsample: 0.9	 accuracy: 0.832772581758835
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 5	 subsample: 0.5	 accuracy: 0.8305191136777352
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 5	 subsample: 0.6	 accuracy: 0.830525390747599
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 5	 subsample: 0.7	 accuracy: 0.8271922666499278
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 5	 subsample: 0.8	 accuracy: 0.8260498399347185
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 5	 subsample: 0.9	 accuracy: 0.8294206264515724
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 6	 subsample: 0.5	 accuracy: 0.8305379448873266
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 6	 subsample: 0.6	 accuracy: 0.8182097796748478
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 6	 subsample: 0.7	 accuracy: 0.8271608813006088
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 6	 subsample: 0.8	 accuracy: 0.8238277572029377
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 6	 subsample: 0.9	 accuracy: 0.8271734354403364
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 7	 subsample: 0.5	 accuracy: 0.8361433682756889
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 7	 subsample: 0.6	 accuracy: 0.8181972255351202
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 7	 subsample: 0.7	 accuracy: 0.8215429037725189
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 7	 subsample: 0.8	 accuracy: 0.8249262444291005
# learning_rate: 0.14	 n_estimators: 100	 max_depth: 7	 subsample: 0.9	 accuracy: 0.8271797125102003

# %%
accuracies_df.sort_values(by="accuracy", ascending=False)
# Out:
#      learning_rate n_estimators max_depth  subsample min_child_weight gamma  \
# 103           0.12           50         7        0.8              NaN   NaN
# 155           0.14           50         6        0.5              NaN   NaN
# 99            0.12           50         6        0.9              NaN   NaN
# 39            0.10           50         6        0.9              NaN   NaN
# 125           0.13           50         6        0.5              NaN   NaN
# ..             ...          ...       ...        ...              ...   ...
# 25            0.99          100         7        0.5              NaN   NaN
# 5             0.99           50         6        0.5              NaN   NaN
# 20            0.99          100         6        0.5              NaN   NaN
# 26            0.99          100         7        0.6              NaN   NaN
# 10            0.99           50         7        0.5              NaN   NaN
#
#     reg_alpha reg_lambda  scale_pos_weight  accuracy
# 103       NaN        NaN          1.605263  0.840638
# 155       NaN        NaN          1.605263  0.839527
# 99        NaN        NaN          1.605263  0.839527
# 39        NaN        NaN          1.605263  0.839520
# 125       NaN        NaN          1.605263  0.839514
# ..        ...        ...               ...       ...
# 25        NaN        NaN          1.605263  0.785657
# 5         NaN        NaN          1.605263  0.784521
# 20        NaN        NaN          1.605263  0.784514
# 26        NaN        NaN          1.605263  0.783378
# 10        NaN        NaN          1.605263  0.782261
#
# [180 rows x 10 columns]

# %%
accuracies_df.to_csv("output/accuracies_tuning.csv")

# %% [markdown]
# Extract the parameters giving the highest value

# %%
accuracies_df_max_row = accuracies_df.loc[
    accuracies_df["accuracy"] == max(accuracies_df["accuracy"])
]
best_lr = accuracies_df_max_row["learning_rate"].iloc[0]
best_n_est = accuracies_df_max_row["n_estimators"].iloc[0]
best_max_dep = accuracies_df_max_row["max_depth"].iloc[0]
best_subsam = accuracies_df_max_row["subsample"].iloc[0]

# %% [markdown]
# ## Fine-tuning

# %% [markdown]
# Fine-tuning:
#
# - Minimum Child Weight (min_child_weight)
#   - Definition: Minimum sum of instance weights (hessian) needed in a child node.
#   - Effect: A larger value results in more conservative models, reducing the risk of overfitting by avoiding splitting nodes with insufficient instances.
#   - Typical Range: 1 to 10 (increase for highly imbalanced datasets).
# - Gamma (gamma)
#   - Definition: Minimum loss reduction required for further splitting a node.
#   - Effect: A higher value makes the algorithm more conservative, reducing the likelihood of overfitting by forcing the algorithm to focus on more significant splits.
#   - Typical Range: 0 to 5 (higher for noisy datasets).
# - Regularization (reg_alpha, reg_lambda)
#   - Definition:
#     - reg_alpha (L1 regularization): Adds L1 regularization, making some weights zero (similar to Lasso regression).
#     - reg_lambda (L2 regularization): Adds L2 regularization (similar to Ridge regression).
#   - Effect: Helps control model complexity and reduce overfitting, particularly in high-dimensional datasets.
#   - Typical Range:
#     - reg_alpha: 0 to 1 (higher values reduce complexity).
#     - reg_lambda: 1 to 5 (higher values reduce overfitting).

# %%
# DataFrame that saves the parameters with accuracies for fine-tuning
accuracies_ft_df = pd.DataFrame(
    columns=[
        "learning_rate",
        "n_estimators",
        "max_depth",
        "subsample",
        "min_child_weight",
        "gamma",
        "reg_alpha",
        "reg_lambda",
        "scale_pos_weight",
        "accuracy",
    ]
)

# %%
min_w_values = [1, 1.025, 1.05]
gam_values = [0, 0.025, 0.05]
reg_a_values = [0, 0.025, 0.05]
reg_l_values = [1, 1.05, 1.1]


for min_w in min_w_values:
    for gam in gam_values:
        for reg_a in reg_a_values:
            for reg_l in reg_l_values:
                acc_list = []
                for train_index, val_index in kf.split(X):
                    # Split the data into training and testing sets
                    X_train, X_val = X[train_index], X[val_index]
                    y_train, y_val = y[train_index], y[val_index]

                    # Init the model in every iteration
                    model = xgb.XGBClassifier(
                        learning_rate=best_lr,
                        n_estimators=best_n_est,
                        max_depth=best_max_dep,
                        subsample=best_subsam,
                        min_child_weight=min_w,
                        gamma=gam,
                        reg_alpha=reg_a,
                        reg_lambda=reg_l,
                        scale_pos_weight=scale_pos_weight,
                    )

                    model.fit(X_train, y_train)
                    y_pred = model.predict(X_val)

                    acc_list.append(sum(y_pred == y_val) / len(y_val))

                print(
                    f"min_child_weight: {min_w}\t gamma: {gam}\t reg_alpha: {reg_a}\t reg_lambda: {reg_l}\t accuracy: {mean(acc_list)}"
                )

                # Create a DataFrame for the new row
                new_row = pd.DataFrame(
                    [
                        [
                            best_lr,
                            best_n_est,
                            best_max_dep,
                            best_subsam,
                            min_w,
                            gam,
                            reg_a,
                            reg_l,
                            scale_pos_weight,
                            mean(acc_list),
                        ]
                    ],
                    columns=[
                        "learning_rate",
                        "n_estimators",
                        "max_depth",
                        "subsample",
                        "min_child_weight",
                        "gamma",
                        "reg_alpha",
                        "reg_lambda",
                        "scale_pos_weight",
                        "accuracy",
                    ],
                )

                # Append the row using pd.concat()
                accuracies_ft_df = pd.concat(
                    [accuracies_ft_df, new_row], ignore_index=True
                )
# Out:
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.8406377502981608
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8350134957002071
# C:\Users\kkleist\AppData\Local\Temp\ipykernel_7748\2513178999.py:70: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   accuracies_ft_df = pd.concat(
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8383905592869249
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8350197727700709
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8361559224154165
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8417738999435064
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8395204318624067
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8361496453455527
# min_child_weight: 1	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8361433682756889
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.837260686711443
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8350260498399347
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8395141547925429
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8383842822170611
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8350197727700709
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8428723871696692
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8361559224154165
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8372795179210345
# min_child_weight: 1	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8361496453455527
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.8372669637813068
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8361496453455527
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.840631473228297
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8361559224154165
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8327914129684263
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8294143493817085
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.845125855250769
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8361433682756889
# min_child_weight: 1	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8327788588286987
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.839507877722679
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8350134957002071
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8339212855439081
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8338899001945892
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8305379448873266
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8417676228736426
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8406251961584332
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8339087314041805
# min_child_weight: 1.025	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8361433682756889
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.8294080723118449
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8372544096415793
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8361433682756889
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8327663046889712
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8372669637813068
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8372732408511707
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8361433682756889
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8339024543343168
# min_child_weight: 1.025	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8406377502981608
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.8372669637813069
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8339024543343168
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8372669637813069
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8339087314041805
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.833896177264453
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8372732408511707
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8395016006528153
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8361496453455527
# min_child_weight: 1.025	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8361433682756889
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.8339087314041805
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8350197727700709
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8372732408511707
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8372669637813068
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8372669637813068
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8372795179210345
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8372669637813068
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8383780051471973
# min_child_weight: 1.05	 gamma: 0	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8417613458037788
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.8383968363567886
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8327788588286987
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.8417487916640513
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8395141547925428
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8350197727700709
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8383968363567886
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8372857949908983
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8305379448873266
# min_child_weight: 1.05	 gamma: 0.025	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8350260498399347
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1	 accuracy: 0.837260686711443
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1.05	 accuracy: 0.8395141547925429
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0	 reg_lambda: 1.1	 accuracy: 0.833896177264453
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1	 accuracy: 0.8395141547925429
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1.05	 accuracy: 0.8339024543343168
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0.025	 reg_lambda: 1.1	 accuracy: 0.8350260498399348
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1	 accuracy: 0.8339087314041805
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1.05	 accuracy: 0.8350197727700709
# min_child_weight: 1.05	 gamma: 0.05	 reg_alpha: 0.05	 reg_lambda: 1.1	 accuracy: 0.8316678174628084

# %%
accuracies_ft_df.sort_values(by="accuracy", ascending=False)
# Out:
#     learning_rate n_estimators max_depth  subsample min_child_weight  gamma  \
# 24           0.12           50         7        0.8                1   0.05
# 14           0.12           50         7        0.8                1  0.025
# 5            0.12           50         7        0.8                1      0
# 32           0.12           50         7        0.8            1.025      0
# 62           0.12           50         7        0.8             1.05      0
# ..            ...          ...       ...        ...              ...    ...
# 80           0.12           50         7        0.8             1.05   0.05
# 70           0.12           50         7        0.8             1.05  0.025
# 31           0.12           50         7        0.8            1.025      0
# 23           0.12           50         7        0.8                1   0.05
# 36           0.12           50         7        0.8            1.025  0.025
#
#    reg_alpha reg_lambda  scale_pos_weight  accuracy
# 24      0.05          1          1.605263  0.845126
# 14     0.025        1.1          1.605263  0.842872
# 5      0.025        1.1          1.605263  0.841774
# 32     0.025        1.1          1.605263  0.841768
# 62      0.05        1.1          1.605263  0.841761
# ..       ...        ...               ...       ...
# 80      0.05        1.1          1.605263  0.831668
# 70      0.05       1.05          1.605263  0.830538
# 31     0.025       1.05          1.605263  0.830538
# 23     0.025        1.1          1.605263  0.829414
# 36         0          1          1.605263  0.829408
#
# [81 rows x 10 columns]

# %%
accuracies_ft_df.to_csv("output/accuracies_fine_tuning.csv")

# %% [markdown]
# Extract the parameters giving the highest value

# %%
accuracies_ft_df_max_row = accuracies_ft_df.loc[
    accuracies_ft_df["accuracy"] == max(accuracies_ft_df["accuracy"])
]
best_min_w = accuracies_ft_df_max_row["min_child_weight"].iloc[0]
best_gam = accuracies_ft_df_max_row["gamma"].iloc[0]
best_reg_a = accuracies_ft_df_max_row["reg_alpha"].iloc[0]
best_reg_l = accuracies_ft_df_max_row["reg_lambda"].iloc[0]

# %% [markdown]
# ## Submit prediction

# %%
model = xgb.XGBClassifier(
    learning_rate=best_lr,
    n_estimators=best_n_est,
    max_depth=best_max_dep,
    subsample=best_subsam,
    min_child_weight=best_min_w,
    gamma=best_gam,
    reg_alpha=best_reg_a,
    reg_lambda=best_reg_l,
    scale_pos_weight=scale_pos_weight,
)

model.fit(X, y)
y_pred = model.predict(X_test)

# %%
predictions = y_pred

# Saving the predictions
output = pd.DataFrame({"PassengerId": test_data.index, "Survived": predictions})
if not os.path.isdir("output/"):
    os.mkdir("output/")
output.to_csv("output/submission.csv", index=False)

print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!
